# %% [markdown]
# <a href="https://colab.research.google.com/github/ridwanmuhammad/100-Days-Of-ML-Code/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("test git")
# Out:
# test git
